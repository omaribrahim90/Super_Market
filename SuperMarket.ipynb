# %%
import os
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns
import kagglehub


path = kagglehub.dataset_download("vivek468/superstore-dataset-final")
print("Path to dataset files:", path)


files = os.listdir(path)
print("Files:", files)

file_path = os.path.join(path, 'Sample - Superstore.csv')
df = pd.read_csv(file_path, encoding='latin1') 
print(df.columns)
# Out:
# Path to dataset files: C:\Users\Mveun\.cache\kagglehub\datasets\vivek468\superstore-dataset-final\versions\1
# Files: ['Sample - Superstore.csv']
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
df.describe(include='all')
# Out:
#              Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# count   9994.000000            9994       9994        9994            9994
# unique          NaN            5009       1237        1334               4
# top             NaN  CA-2017-100111   9/5/2016  12/16/2015  Standard Class
# freq            NaN              14         38          35            5968
# mean    4997.500000             NaN        NaN         NaN             NaN
# std     2885.163629             NaN        NaN         NaN             NaN
# min        1.000000             NaN        NaN         NaN             NaN
# 25%     2499.250000             NaN        NaN         NaN             NaN
# 50%     4997.500000             NaN        NaN         NaN             NaN
# 75%     7495.750000             NaN        NaN         NaN             NaN
# max     9994.000000             NaN        NaN         NaN             NaN
#
#        Customer ID  Customer Name   Segment        Country           City  \
# count         9994           9994      9994           9994           9994
# unique         793            793         3              1            531
# top       WB-21850  William Brown  Consumer  United States  New York City
# freq            37             37      5191           9994            915
# mean           NaN            NaN       NaN            NaN            NaN
# std            NaN            NaN       NaN            NaN            NaN
# min            NaN            NaN       NaN            NaN            NaN
# 25%            NaN            NaN       NaN            NaN            NaN
# 50%            NaN            NaN       NaN            NaN            NaN
# 75%            NaN            NaN       NaN            NaN            NaN
# max            NaN            NaN       NaN            NaN            NaN
#
#         ...   Postal Code  Region       Product ID         Category  \
# count   ...   9994.000000    9994             9994             9994
# unique  ...           NaN       4             1862                3
# top     ...           NaN    West  OFF-PA-10001970  Office Supplies
# freq    ...           NaN    3203               19             6026
# mean    ...  55190.379428     NaN              NaN              NaN
# std     ...  32063.693350     NaN              NaN              NaN
# min     ...   1040.000000     NaN              NaN              NaN
# 25%     ...  23223.000000     NaN              NaN              NaN
# 50%     ...  56430.500000     NaN              NaN              NaN
# 75%     ...  90008.000000     NaN              NaN              NaN
# max     ...  99301.000000     NaN              NaN              NaN
#
#        Sub-Category     Product Name         Sales     Quantity     Discount  \
# count          9994             9994   9994.000000  9994.000000  9994.000000
# unique           17             1850           NaN          NaN          NaN
# top         Binders  Staple envelope           NaN          NaN          NaN
# freq           1523               48           NaN          NaN          NaN
# mean            NaN              NaN    229.858001     3.789574     0.156203
# std             NaN              NaN    623.245101     2.225110     0.206452
# min             NaN              NaN      0.444000     1.000000     0.000000
# 25%             NaN              NaN     17.280000     2.000000     0.000000
# 50%             NaN              NaN     54.490000     3.000000     0.200000
# 75%             NaN              NaN    209.940000     5.000000     0.200000
# max             NaN              NaN  22638.480000    14.000000     0.800000
#
#              Profit
# count   9994.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean      28.656896
# std      234.260108
# min    -6599.978000
# 25%        1.728750
# 50%        8.666500
# 75%       29.364000
# max     8399.976000
#
# [11 rows x 21 columns]

# %%
df.sample(15)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 5458    5459  CA-2017-116680    9/4/2017    9/6/2017    Second Class
# 1627    1628  CA-2015-143119   9/24/2015   9/30/2015  Standard Class
# 5052    5053  US-2017-120607   5/19/2017   5/19/2017        Same Day
# 9873    9874  CA-2016-100587  12/10/2016  12/14/2016  Standard Class
# 3412    3413  CA-2016-100244   9/20/2016   9/24/2016  Standard Class
# 1991    1992  CA-2017-111374   2/24/2017   2/28/2017  Standard Class
# 7090    7091  CA-2015-119480    1/9/2015   1/13/2015  Standard Class
# 5313    5314  CA-2017-137876   4/30/2017    5/5/2017  Standard Class
# 8005    8006  CA-2014-143210   12/1/2014   12/3/2014     First Class
# 9759    9760  CA-2016-146913  10/31/2016   11/5/2016  Standard Class
# 3367    3368  CA-2014-165379    7/9/2014   7/15/2014  Standard Class
# 4671    4672  CA-2016-133550   7/31/2016    8/6/2016  Standard Class
# 2602    2603  CA-2016-165848    6/4/2016    6/4/2016        Same Day
# 9404    9405  CA-2017-141663   4/13/2017   4/17/2017  Standard Class
# 9139    9140  CA-2014-106971    9/2/2014    9/8/2014  Standard Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 5458    PK-19075         Pete Kriz     Consumer  United States  San Francisco
# 1627    MC-17275        Marc Crier     Consumer  United States      Lafayette
# 5052    JC-15775      John Castell     Consumer  United States        Atlanta
# 9873    SL-20155    Sara Luxemburg  Home Office  United States  New York City
# 3412    GM-14695      Greg Maxwell    Corporate  United States  San Francisco
# 1991    CB-12415  Christy Brittain     Consumer  United States   Philadelphia
# 7090    CC-12685     Craig Carroll     Consumer  United States      Henderson
# 5313    DJ-13510         Don Jones    Corporate  United States  San Francisco
# 8005    AA-10645     Anna Andreadi     Consumer  United States         Lowell
# 9759    SF-20965   Sylvia Foulston    Corporate  United States  San Francisco
# 3367    BM-11650        Brian Moss    Corporate  United States         Dallas
# 4671    KL-16645      Ken Lonsdale     Consumer  United States        Detroit
# 2602    EN-13780     Edward Nazzal     Consumer  United States  New York City
# 9404    DP-13105      Dave Poirier    Corporate  United States   Philadelphia
# 9139    BM-11785       Bryan Mills     Consumer  United States  Buffalo Grove
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 5458  ...       94122     West  OFF-BI-10004022  Office Supplies      Binders
# 1627  ...       70506    South  FUR-CH-10001270        Furniture       Chairs
# 5052  ...       30318    South  OFF-PA-10003129  Office Supplies        Paper
# 9873  ...       10024     East  OFF-PA-10004609  Office Supplies        Paper
# 3412  ...       94122     West  OFF-AR-10000940  Office Supplies          Art
# 1991  ...       19134     East  OFF-BI-10004970  Office Supplies      Binders
# 7090  ...       42420    South  OFF-PA-10000474  Office Supplies        Paper
# 5313  ...       94110     West  FUR-FU-10000222        Furniture  Furnishings
# 8005  ...        1852     East  FUR-FU-10002268        Furniture  Furnishings
# 9759  ...       94109     West  FUR-CH-10001854        Furniture       Chairs
# 3367  ...       75217  Central  OFF-PA-10002245  Office Supplies        Paper
# 4671  ...       48205  Central  OFF-AP-10001005  Office Supplies   Appliances
# 2602  ...       10035     East  TEC-MA-10003356       Technology     Machines
# 9404  ...       19134     East  OFF-FA-10004076  Office Supplies    Fasteners
# 9139  ...       60089  Central  TEC-AC-10000844       Technology  Accessories
#
#                                            Product Name     Sales  Quantity  \
# 5458           Acco Suede Grain Vinyl Round Ring Binder    13.344         6
# 1627              Harbour Creations Steel Folding Chair   517.500         6
# 5052                 Tops White Computer Printout Paper   195.640         4
# 9873                                          Xerox 221     6.480         1
# 3412                                         Newell 343    11.760         4
# 1991                   ACCOHIDE 3-Ring Binder, Blue, 1"     4.956         4
# 7090                                  Easy-staple paper   106.320         3
# 5313                   Seth Thomas 16" Steel Case Clock    64.960         2
# 8005                              Ultra Door Push Plate     9.820         2
# 9759  Office Star - Professional Matrix Back Chair w...  1403.920         5
# 3367                                         Xerox 1895    14.352         3
# 4671               Honeywell Quietcare HEPA Air Cleaner   283.140         4
# 2602  Panasonic KX MC6040 Color Laser Multifunction ...  1349.850         3
# 9404                       Translucent Push Pins by OIC     7.920         5
# 9139                   Logitech Gaming G510s - Keyboard   475.944         7
#
#       Discount    Profit
# 5458       0.2    4.3368
# 1627       0.0  155.2500
# 5052       0.0   91.9508
# 9873       0.0    3.1104
# 3412       0.0    3.1752
# 1991       0.7   -3.7996
# 7090       0.0   49.9704
# 5313       0.0   21.4368
# 8005       0.0    3.2406
# 9759       0.2   70.1960
# 3367       0.2    4.4850
# 4671       0.1   72.3580
# 2602       0.0  364.4595
# 9404       0.2    1.6830
# 9139       0.2   95.1888
#
# [15 rows x 21 columns]

# %% [markdown]
# # Data cleaning

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df['Month'] = df['Order Date'].dt.month

# %% [markdown]
# # Analysis

# %%
# orders per region , Note : we have 0 orders from "North" so we We excluded 
region_counts = df['Region'].value_counts()
labels = ['South', 'West', 'East' , 'central']

plt.figure(figsize=(8,6))
plt.pie(region_counts, labels=labels, autopct='%1.1f%%', startangle=90)
plt.title("Orders per region ")
plt.axis('equal')
plt.show()

sns.countplot(data=df, x='Region')
plt.title('Orders per region')
plt.show()

region_counts
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
# top cities in each region

Top_List = [
    (region, df[df['Region'] == region]['City'].value_counts().head())
    for region in df['Region'].unique()
]

def plot_top_cities(top_list):
    plt.figure(figsize=(12, 8))
    palettes = ['Blues_r', 'Greens_r', 'Oranges_r', 'Purples_r'] 
    
    for i, (region, data) in enumerate(top_list, start=1):
        ax = plt.subplot(2, 2, i)
        bars = sns.barplot(
            x=data.values,
            y=data.index,
            hue=data.index,
            palette=palettes[i-1],
            legend=False,
            ax=ax
        )

        for bar in bars.patches:
            value = int(bar.get_width())
            text_x = bar.get_width() + (max(data.values) * 0.01) 
            text_y = bar.get_y() + bar.get_height() / 2
            ax.text(text_x, text_y, str(value), va='center')

        ax.set_title(f'Top 5 Cities in {region} Region')
        ax.set_xlabel('Number of Orders')
        ax.set_ylabel('City')

    plt.tight_layout()
    plt.show()

plot_top_cities(Top_List)

# %%
#profit in each region
table = df.pivot_table(index='Region', values=['Sales', 'Profit'], aggfunc='sum')
table.sort_values(by='Profit', ascending=False)

table['Profit_Margin'] = (table['Profit'] / table['Sales']) * 100

table

table['Profit_Margin'].plot(kind='bar' , x='region' , y= 'Profit_Margin')
plt.xlabel('Region')  
plt.ylabel('Profit margin in percentage')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

table
# Out:
#               Profit        Sales  Profit_Margin
# Region
# Central   39706.3625  501239.8908       7.921629
# East      91522.7800  678781.2400      13.483399
# South     46749.4303  391721.9050      11.934342
# West     108418.4489  725457.8245      14.944831

# %%
# Most purchased products
top_product = df['Product Name'].value_counts().head()

top_product.plot(kind='bar', title='Top 5 Best-Selling Products')
plt.xlabel('Product Name')  
plt.ylabel('Number of Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sns.countplot(data=df , x='Segment')
plt.title('Orders by segment')
plt.show

df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64
